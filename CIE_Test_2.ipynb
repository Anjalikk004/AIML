# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjalikk004/AIML/blob/main/CIE_Test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Keep the missing value as is
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
print("keep the missing value as is")
print(df)
# Out:
# keep the missing value as is
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#remove the attribute with missing value
df=df.dropna(axis=1)
print("remove the attribute with missing value")
print(df)
# Out:
# remove the attribute with missing value
#       Customer ID  Age  Gender Item Purchased  Purchase Amount (USD)  \
# 0               1   55    Male         Blouse                     53
# 1               2   19    Male        Sweater                     64
# 2               3   50    Male          Jeans                     73
# 3               4   21    Male        Sandals                     90
# 4               5   45    Male         Blouse                     49
# ...           ...  ...     ...            ...                    ...
# 3895         3896   40  Female         Hoodie                     28
# 3896         3897   52  Female       Backpack                     49
# 3897         3898   46  Female           Belt                     33
# 3898         3899   44  Female          Shoes                     77
# 3899         3900   52  Female        Handbag                     81
#
#            Location Size      Color  Season  Review Rating  \
# ...

# %%
#Remove the rows with missing values
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df=df.isna().mean()
print("remove the rows with missing values")
print(df)
# Out:
# remove the rows with missing values
# Customer ID                 0.0
# Age                         0.0
# Gender                      0.0
# Item Purchased              0.0
# Category                    0.0
# Purchase Amount (USD)       0.0
# Location                    0.0
# Size                        0.0
# Color                       0.0
# Season                      0.0
# Review Rating               0.0
# Subscription Status         0.0
# Payment Method              0.0
# Shipping Type               0.0
# Discount Applied            0.0
# Promo Code Used             0.0
# Previous Purchases          0.0
# Preferred Payment Method    0.0
# Frequency of Purchases      0.0
# dtype: float64

# %%
#Estimate and impute the missing value
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df=df.fillna(df.mean(numeric_only=True))
print("estimate and impute the missing value")
print(df)
# Out:
# estimate and impute the missing value
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df=df.fillna(df.median(numeric_only=True))
print("estimate and impute the missing value")
print(df)
# Out:
# estimate and impute the missing value
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#intigration
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler
data=df[['Age','Review Rating']]
target=StandardScaler().fit_transform(data)
print(target)
# Out:
# [[ 0.71891344 -0.90758357]
#  [-1.64862924 -0.90758357]
#  [ 0.39008807 -0.90758357]
#  ...
#  [ 0.12702777 -1.18686209]
#  [-0.00450238  0.06989124]
#  [ 0.52161822 -0.90758357]]

# %%
#log transformation
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df['Age']=df['Age'].apply(lambda x:np.log(x))
print("log transformation")
print(df)
# Out:
# log transformation
#       Customer ID       Age  Gender Item Purchased     Category  \
# 0               1  4.007333    Male         Blouse     Clothing
# 1               2  2.944439    Male        Sweater     Clothing
# 2               3  3.912023    Male          Jeans     Clothing
# 3               4  3.044522    Male        Sandals     Footwear
# 4               5  3.806662    Male         Blouse     Clothing
# ...           ...       ...     ...            ...          ...
# 3895         3896  3.688879  Female         Hoodie     Clothing
# 3896         3897  3.951244  Female       Backpack  Accessories
# 3897         3898  3.828641  Female           Belt  Accessories
# 3898         3899  3.784190  Female          Shoes     Footwear
# 3899         3900  3.951244  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# ...

# %%
#Donothing
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
print(df)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#replace with upper and lower cap
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
upper_cap=50
lower_cap=4
data=df["Age"]
result=data.clip(lower=lower_cap,upper=upper_cap)
print(result)
# Out:
# 0       50
# 1       19
# 2       50
# 3       21
# 4       45
#         ..
# 3895    40
# 3896    50
# 3897    46
# 3898    44
# 3899    50
# Name: Age, Length: 3900, dtype: int64

# %%
#ranking transformation
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df['Age']=df['Age'].rank()
print("ranking transformation")
print(df)
# Out:
# ranking transformation
#       Customer ID     Age  Gender Item Purchased     Category  \
# 0               1  2759.0    Male         Blouse     Clothing
# 1               2   110.0    Male        Sweater     Clothing
# 2               3  2383.0    Male          Jeans     Clothing
# 3               4   247.0    Male        Sandals     Footwear
# 4               5  2006.5    Male         Blouse     Clothing
# ...           ...     ...     ...            ...          ...
# 3895         3896  1638.5  Female         Hoodie     Clothing
# 3896         3897  2533.0  Female       Backpack  Accessories
# 3897         3898  2080.5  Female           Belt  Accessories
# 3898         3899  1945.0  Female          Shoes     Footwear
# 3899         3900  2533.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# ...

# %%
#z-score
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df['Age']=(df['Age']-df['Age'].mean())/df['Age'].std()
print("z-score")
print(df)
# Out:
# z-score
#       Customer ID       Age  Gender Item Purchased     Category  \
# 0               1  0.718821    Male         Blouse     Clothing
# 1               2 -1.648418    Male        Sweater     Clothing
# 2               3  0.390038    Male          Jeans     Clothing
# 3               4 -1.516905    Male        Sandals     Footwear
# 4               5  0.061255    Male         Blouse     Clothing
# ...           ...       ...     ...            ...          ...
# 3895         3896 -0.267528  Female         Hoodie     Clothing
# 3896         3897  0.521551  Female       Backpack  Accessories
# 3897         3898  0.127011  Female           Belt  Accessories
# 3898         3899 -0.004502  Female          Shoes     Footwear
# 3899         3900  0.521551  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# ...

# %%
#binarycode tarnsformation
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df['Gender']=df['Gender'].apply(lambda x:1 if x=='Female' else 0)
print("binarycode tarnsformation")
print(df)
# Out:
# binarycode tarnsformation
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55       0         Blouse     Clothing
# 1               2   19       0        Sweater     Clothing
# 2               3   50       0          Jeans     Clothing
# 3               4   21       0        Sandals     Footwear
# 4               5   45       0         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40       1         Hoodie     Clothing
# 3896         3897   52       1       Backpack  Accessories
# 3897         3898   46       1           Belt  Accessories
# 3898         3899   44       1          Shoes     Footwear
# 3899         3900   52       1        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#IQR
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
Q1=df['Previous Purchases'].quantile(0.25)
Q3=df['Previous Purchases'].quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# 25.0

# %%
#standerdiztion
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df['Previous Purchases']=df['Previous Purchases'].mean(numeric_only=True)/df.std(numeric_only=True)
print("standerdiztion")
print(df)
# Out:
# standerdiztion
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
#data reduction
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df=df.drop(['Gender'],axis=1)
print("data reduction")
print(df)
# Out:
# data reduction
#       Customer ID  Age Item Purchased     Category  Purchase Amount (USD)  \
# 0               1   55         Blouse     Clothing                     53
# 1               2   19        Sweater     Clothing                     64
# 2               3   50          Jeans     Clothing                     73
# 3               4   21        Sandals     Footwear                     90
# 4               5   45         Blouse     Clothing                     49
# ...           ...  ...            ...          ...                    ...
# 3895         3896   40         Hoodie     Clothing                     28
# 3896         3897   52       Backpack  Accessories                     49
# 3897         3898   46           Belt  Accessories                     33
# 3898         3899   44          Shoes     Footwear                     77
# 3899         3900   52        Handbag  Accessories                     81
#
#            Location Size      Color  Season  Review Rating  \
# ...

# %%
#data redendency
import pandas as pd
df=pd.read_csv("/content/shopping_trends.csv")
df=df.drop(['Location'],axis=1)
print("data redendency")
print(df)
# Out:
# data redendency
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD) Size      Color  Season  Review Rating  \
# 0                        53    L       Gray  Winter            3.1
# 1                        64    L     Maroon  Winter            3.1
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000
